# %% [markdown]
# <a href="https://colab.research.google.com/github/chavitdew/python-for-devops/blob/main/getting_started_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction to Python

# %% [markdown]
# ### Statement in Python

# %%
print("Hello World!!")
# Out:
# Hello World!!

# %%
name = "John"
print(f"Hello {name}")
# Out:
# Hello John

# %% [markdown]
# ### Datastructures:List and Dictionaries

# %% [markdown]
# #### Lists

# %%
fruits = ["apple","banana","orange","kiwi"]

# %%
type(fruits)
# Out:
# list

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[:-1]
# Out:
# ['apple', 'banana', 'orange']

# %%
for my_fruit in fruits :
  print(f"My favorite fruit is {my_fruit}")
# Out:
# My favorite fruit is apple
# My favorite fruit is banana
# My favorite fruit is orange
# My favorite fruit is kiwi

# %% [markdown]
# #### Dictionaries

# %%
meals = {"breakfast":"black coffee","lunch":"salad","dinner":"pizza"}

# %%
meals.keys()
# Out:
# dict_keys(['breakfast', 'lunch', 'dinner'])

# %%
meals.values()
# Out:
# dict_values(['black coffee', 'salad', 'pizza'])

# %%
for meals_name , meals_item in meals.items() :
  print(f"This meal is {meals_name} is when I like to consume {meals_item}")
# Out:
# This meal is breakfast is when I like to consume black coffee
# This meal is lunch is when I like to consume salad
# This meal is dinner is when I like to consume pizza
